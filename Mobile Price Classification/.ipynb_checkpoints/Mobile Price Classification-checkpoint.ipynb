# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
sns.barplot(data=train, x="price_range", y="battery_power")
plt.xlabel("Price range")
plt.ylabel("Battery power")
plt.show()

# %%
sns.barplot(data=train, x="price_range", y="fc")
plt.xlabel("Price range")
plt.ylabel("Front camera mega pixel")
plt.show()

# %%
sns.barplot(data=train, x="price_range", y="int_memory")
plt.xlabel("Price range")
plt.ylabel("Internal memory")
plt.show()

# %%
sns.barplot(data=train, x="price_range", y="m_dep")
plt.xlabel("Price range")
plt.ylabel("Mobile depth")
plt.show()

# %%
sns.barplot(data=train, x="price_range", y="mobile_wt")
plt.xlabel("Price range")
plt.ylabel("Mobile weight")
plt.show()
